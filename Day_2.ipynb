# %% [markdown]
# <a href="https://colab.research.google.com/github/Smith-S-S/30_days_Workshop/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pwd
# Out:
# '/content'

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import PIL
import glob
import cv2
import matplotlib as mp
import imutils

# %%
# pip uninstall imutils
#  pip install imutils==0.5.4 
"""for version"""

# %%
os.chdir('/content/gdrive/MyDrive/30 DAYS WORKSHOP/IMAGES')

# %%
img = cv2.imread('101.jpg')

# %%
#cv2.imwrite("new",img) 
# saving

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
#cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=801x1166 at 0x7F3A04682590>

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#plt.imshow(gray)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=801x1166 at 0x7F3A02DD5A10>

# %%
plt.imshow(gray) #using the matplotlib

# %%
#thresholding 
# if the image is in the certain colour we can chage the image to black and white

# %%
thresholding= cv2.threshold(gray,200,255,cv2.THRESH_BINARY)[1]

# %%
plt.imshow(thresholding)

# %%
#for video

# %%
vide=cv2.VideoCapture(0)
while True:
  _,img=vide.read()# 2 value (camera is working or not)
  cv2.imshow(img)
  key=cv2.waitKey(0) & 0xFF
  if key==ord("s"):
    break
v.relaesed()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-30-eb10f1f1c077> in <module>
#       2 while True:
#       3   _,img=vide.read()# 2 value (camera is working or not)
# ----> 4   cv2.imshow(img)
#       5   key=cv2.waitKey(0) & 0xFF
#       6   if key==ord("s"):
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
cap = cv2.VideoCapture(0)
ret, image = cap.read()
image=cv2.resize(image,None,fx=0.25,fy=0.25,interpolation=cv2.INTER_AREA)
plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-33-209538a2aa7f> in <module>
#       4 cap = cv2.VideoCapture(0)
#       5 ret, image = cap.read()
# ----> 6 image=cv2.resize(image,None,fx=0.25,fy=0.25,interpolation=cv2.INTER_AREA)
#       7 plt.imshow(image)
#       8 plt.show()
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
np.shape("img")
# Out:
# ()
